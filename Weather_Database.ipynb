# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 606

# %%
import requests
from config import api2_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api2_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tasiilaq
# Processing Record 2 of Set 1 | sorland
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | avarua
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | kodiak
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | upernavik
# Processing Record 10 of Set 1 | airai
# Processing Record 11 of Set 1 | mananara
# Processing Record 12 of Set 1 | chuy
# Processing Record 13 of Set 1 | tam ky
# Processing Record 14 of Set 1 | sao filipe
# Processing Record 15 of Set 1 | isangel
# Processing Record 16 of Set 1 | liuhe
# Processing Record 17 of Set 1 | college
# Processing Record 18 of Set 1 | hami
# Processing Record 19 of Set 1 | castro
# Processing Record 20 of Set 1 | sumbe
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | saint anthony
# Processing Record 23 of Set 1 | rodrigues alves
# Processing Record 24 of Set 1 | rio grande
# Processing Record 25 of Set 1 | balakhta
# Processing Record 26 of Set 1 | port macquarie
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | revda
# Processing Record 29 of Set 1 | voskresenskoye
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | zyryanskoye
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | bengkulu
# Processing Record 34 of Set 1 | armacao dos buzios
# City not found. Skipping...
# Processing Record 35 of Set 1 | launceston
# Processing Record 36 of Set 1 | arzgir
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | hithadhoo
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | fasa
# Processing Record 42 of Set 1 | hilo
# Processing Record 43 of Set 1 | carnarvon
# Processing Record 44 of Set 1 | saint-philippe
# Processing Record 45 of Set 1 | tiksi
# Processing Record 46 of Set 1 | san andres
# Processing Record 47 of Set 1 | fortuna
# Processing Record 48 of Set 1 | vestmannaeyjar
# Processing Record 49 of Set 1 | victoria
# Processing Record 50 of Set 1 | praia
# Processing Record 1 of Set 2 | namibe
# Processing Record 2 of Set 2 | lasa
# Processing Record 3 of Set 2 | emirdag
# Processing Record 4 of Set 2 | butaritari
# Processing Record 5 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 2 | cape town
# Processing Record 7 of Set 2 | chopovychi
# Processing Record 8 of Set 2 | mataura
# Processing Record 9 of Set 2 | kawalu
# Processing Record 10 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 2 | bontang
# Processing Record 12 of Set 2 | luderitz
# Processing Record 13 of Set 2 | la rioja
# Processing Record 14 of Set 2 | staryy nadym
# Processing Record 15 of Set 2 | saskylakh
# Processing Record 16 of Set 2 | solnechnyy
# Processing Record 17 of Set 2 | katherine
# Processing Record 18 of Set 2 | port elizabeth
# Processing Record 19 of Set 2 | camocim
# Processing Record 20 of Set 2 | ijaki
# City not found. Skipping...
# Processing Record 21 of Set 2 | channapatna
# Processing Record 22 of Set 2 | punta arenas
# Processing Record 23 of Set 2 | bissau
# Processing Record 24 of Set 2 | haverfordwest
# Processing Record 25 of Set 2 | kangaba
# Processing Record 26 of Set 2 | tomatlan
# Processing Record 27 of Set 2 | khani
# Processing Record 28 of Set 2 | acarau
# Processing Record 29 of Set 2 | tilichiki
# Processing Record 30 of Set 2 | esperance
# Processing Record 31 of Set 2 | patawag
# Processing Record 32 of Set 2 | nouadhibou
# Processing Record 33 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 2 | qaanaaq
# Processing Record 35 of Set 2 | dongsheng
# Processing Record 36 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 37 of Set 2 | bluff
# Processing Record 38 of Set 2 | barrow
# Processing Record 39 of Set 2 | lata
# Processing Record 40 of Set 2 | bolivar
# Processing Record 41 of Set 2 | marivan
# Processing Record 42 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 2 | tuktoyaktuk
# Processing Record 44 of Set 2 | silver city
# Processing Record 45 of Set 2 | mahebourg
# Processing Record 46 of Set 2 | liku
# Processing Record 47 of Set 2 | bethel
# Processing Record 48 of Set 2 | pevek
# Processing Record 49 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 2 | bathsheba
# Processing Record 1 of Set 3 | khash
# Processing Record 2 of Set 3 | geraldton
# Processing Record 3 of Set 3 | dikson
# Processing Record 4 of Set 3 | cabo san lucas
# Processing Record 5 of Set 3 | anito
# Processing Record 6 of Set 3 | phuket
# Processing Record 7 of Set 3 | karauzyak
# City not found. Skipping...
# Processing Record 8 of Set 3 | norfolk
# Processing Record 9 of Set 3 | taltal
# Processing Record 10 of Set 3 | gladstone
# Processing Record 11 of Set 3 | bhag
# Processing Record 12 of Set 3 | sitka
# Processing Record 13 of Set 3 | torbay
# Processing Record 14 of Set 3 | narsaq
# Processing Record 15 of Set 3 | bambous virieux
# Processing Record 16 of Set 3 | griffith
# Processing Record 17 of Set 3 | katsuura
# Processing Record 18 of Set 3 | esmeraldas
# Processing Record 19 of Set 3 | saint george
# Processing Record 20 of Set 3 | margate
# Processing Record 21 of Set 3 | byron bay
# Processing Record 22 of Set 3 | lhuntshi
# City not found. Skipping...
# Processing Record 23 of Set 3 | san lawrenz
# Processing Record 24 of Set 3 | santa isabel do rio negro
# Processing Record 25 of Set 3 | ancud
# Processing Record 26 of Set 3 | nago
# Processing Record 27 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 3 | vallenar
# Processing Record 29 of Set 3 | georgetown
# Processing Record 30 of Set 3 | nanortalik
# Processing Record 31 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 3 | east london
# Processing Record 33 of Set 3 | pangody
# Processing Record 34 of Set 3 | iqaluit
# Processing Record 35 of Set 3 | nogent-le-rotrou
# Processing Record 36 of Set 3 | atuona
# Processing Record 37 of Set 3 | labuhan
# Processing Record 38 of Set 3 | ferrol
# Processing Record 39 of Set 3 | puerto ayora
# Processing Record 40 of Set 3 | pauini
# Processing Record 41 of Set 3 | arraial do cabo
# Processing Record 42 of Set 3 | romny
# Processing Record 43 of Set 3 | shetpe
# Processing Record 44 of Set 3 | muisne
# Processing Record 45 of Set 3 | marrakesh
# Processing Record 46 of Set 3 | thompson
# Processing Record 47 of Set 3 | ko samui
# Processing Record 48 of Set 3 | grand-santi
# Processing Record 49 of Set 3 | provideniya
# Processing Record 50 of Set 3 | verkhoyansk
# Processing Record 1 of Set 4 | wuwei
# Processing Record 2 of Set 4 | marawi
# Processing Record 3 of Set 4 | haian
# Processing Record 4 of Set 4 | coquimbo
# Processing Record 5 of Set 4 | taoudenni
# Processing Record 6 of Set 4 | cockburn town
# Processing Record 7 of Set 4 | nikolayevsk-na-amure
# Processing Record 8 of Set 4 | severo-kurilsk
# Processing Record 9 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 4 | baykit
# Processing Record 11 of Set 4 | capanema
# Processing Record 12 of Set 4 | kamenka
# Processing Record 13 of Set 4 | khatanga
# Processing Record 14 of Set 4 | la ronge
# Processing Record 15 of Set 4 | new norfolk
# Processing Record 16 of Set 4 | abu samrah
# Processing Record 17 of Set 4 | vetluga
# Processing Record 18 of Set 4 | capitao poco
# Processing Record 19 of Set 4 | voh
# Processing Record 20 of Set 4 | parabel
# Processing Record 21 of Set 4 | catuday
# Processing Record 22 of Set 4 | camacha
# Processing Record 23 of Set 4 | ribeira grande
# Processing Record 24 of Set 4 | chabahar
# Processing Record 25 of Set 4 | salalah
# Processing Record 26 of Set 4 | half moon bay
# Processing Record 27 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 4 | pemangkat
# Processing Record 29 of Set 4 | adrar
# Processing Record 30 of Set 4 | muroto
# Processing Record 31 of Set 4 | cidreira
# Processing Record 32 of Set 4 | moroto
# Processing Record 33 of Set 4 | ahipara
# Processing Record 34 of Set 4 | gayny
# Processing Record 35 of Set 4 | asau
# Processing Record 36 of Set 4 | vanimo
# Processing Record 37 of Set 4 | norman wells
# Processing Record 38 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 4 | carnot
# Processing Record 40 of Set 4 | nishihara
# Processing Record 41 of Set 4 | alta floresta
# Processing Record 42 of Set 4 | vaini
# Processing Record 43 of Set 4 | babayurt
# Processing Record 44 of Set 4 | trairi
# Processing Record 45 of Set 4 | los llanos de aridane
# Processing Record 46 of Set 4 | vanavara
# Processing Record 47 of Set 4 | souillac
# Processing Record 48 of Set 4 | nikolskoye
# Processing Record 49 of Set 4 | kaitangata
# Processing Record 50 of Set 4 | goderich
# Processing Record 1 of Set 5 | ovada
# Processing Record 2 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 3 of Set 5 | kashi
# Processing Record 4 of Set 5 | ponta do sol
# Processing Record 5 of Set 5 | lompoc
# Processing Record 6 of Set 5 | klimkovice
# Processing Record 7 of Set 5 | vila velha
# Processing Record 8 of Set 5 | port blair
# Processing Record 9 of Set 5 | la union
# Processing Record 10 of Set 5 | liverpool
# Processing Record 11 of Set 5 | barwaha
# City not found. Skipping...
# Processing Record 12 of Set 5 | brazzaville
# Processing Record 13 of Set 5 | samarai
# Processing Record 14 of Set 5 | kruisfontein
# Processing Record 15 of Set 5 | cherskiy
# Processing Record 16 of Set 5 | sur
# Processing Record 17 of Set 5 | gizo
# Processing Record 18 of Set 5 | hamilton
# Processing Record 19 of Set 5 | auki
# Processing Record 20 of Set 5 | gniezno
# Processing Record 21 of Set 5 | veraval
# Processing Record 22 of Set 5 | takoradi
# Processing Record 23 of Set 5 | traverse city
# Processing Record 24 of Set 5 | gizycko
# Processing Record 25 of Set 5 | haines junction
# Processing Record 26 of Set 5 | bilma
# Processing Record 27 of Set 5 | mantua
# Processing Record 28 of Set 5 | port alfred
# Processing Record 29 of Set 5 | lagunas
# Processing Record 30 of Set 5 | kropotkin
# Processing Record 31 of Set 5 | knysna
# Processing Record 32 of Set 5 | klamath falls
# Processing Record 33 of Set 5 | masindi
# Processing Record 34 of Set 5 | angoche
# Processing Record 35 of Set 5 | florianopolis
# Processing Record 36 of Set 5 | ketchikan
# Processing Record 37 of Set 5 | constitucion
# Processing Record 38 of Set 5 | mar del plata
# Processing Record 39 of Set 5 | acajutla
# Processing Record 40 of Set 5 | inta
# Processing Record 41 of Set 5 | caborca
# Processing Record 42 of Set 5 | iskateley
# Processing Record 43 of Set 5 | ostrovnoy
# Processing Record 44 of Set 5 | cayenne
# Processing Record 45 of Set 5 | aykhal
# Processing Record 46 of Set 5 | grootfontein
# Processing Record 47 of Set 5 | te anau
# Processing Record 48 of Set 5 | amga
# Processing Record 49 of Set 5 | narasannapeta
# Processing Record 50 of Set 5 | tapiramuta
# Processing Record 1 of Set 6 | diego de almagro
# Processing Record 2 of Set 6 | katobu
# Processing Record 3 of Set 6 | chokurdakh
# Processing Record 4 of Set 6 | bonavista
# Processing Record 5 of Set 6 | viedma
# Processing Record 6 of Set 6 | anadyr
# Processing Record 7 of Set 6 | klaksvik
# Processing Record 8 of Set 6 | pangnirtung
# Processing Record 9 of Set 6 | salekhard
# Processing Record 10 of Set 6 | paamiut
# Processing Record 11 of Set 6 | kaseda
# Processing Record 12 of Set 6 | washougal
# Processing Record 13 of Set 6 | danville
# Processing Record 14 of Set 6 | waddan
# Processing Record 15 of Set 6 | coihaique
# Processing Record 16 of Set 6 | naze
# Processing Record 17 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 6 | faanui
# Processing Record 19 of Set 6 | oistins
# Processing Record 20 of Set 6 | olafsvik
# Processing Record 21 of Set 6 | zelenoborskiy
# Processing Record 22 of Set 6 | colombo
# Processing Record 23 of Set 6 | tazovskiy
# Processing Record 24 of Set 6 | sorokino
# Processing Record 25 of Set 6 | sri aman
# Processing Record 26 of Set 6 | palmer
# Processing Record 27 of Set 6 | ha tinh
# Processing Record 28 of Set 6 | nha trang
# Processing Record 29 of Set 6 | saint-leu
# Processing Record 30 of Set 6 | hasaki
# Processing Record 31 of Set 6 | koupela
# Processing Record 32 of Set 6 | serenje
# Processing Record 33 of Set 6 | srednekolymsk
# Processing Record 34 of Set 6 | raudeberg
# Processing Record 35 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 6 | bacolod
# Processing Record 37 of Set 6 | puerto quijarro
# Processing Record 38 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 39 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 6 | oranjemund
# Processing Record 41 of Set 6 | fort nelson
# Processing Record 42 of Set 6 | quatre cocos
# Processing Record 43 of Set 6 | along
# Processing Record 44 of Set 6 | ajdabiya
# Processing Record 45 of Set 6 | talnakh
# Processing Record 46 of Set 6 | goure
# Processing Record 47 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 6 | megion
# Processing Record 49 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 50 of Set 6 | edson
# Processing Record 1 of Set 7 | flin flon
# Processing Record 2 of Set 7 | celestun
# Processing Record 3 of Set 7 | berlevag
# Processing Record 4 of Set 7 | grand gaube
# Processing Record 5 of Set 7 | dalbandin
# Processing Record 6 of Set 7 | bubaque
# Processing Record 7 of Set 7 | lavrentiya
# Processing Record 8 of Set 7 | manzil jamil
# City not found. Skipping...
# Processing Record 9 of Set 7 | longyearbyen
# Processing Record 10 of Set 7 | guirang
# Processing Record 11 of Set 7 | waingapu
# Processing Record 12 of Set 7 | sao gabriel da cachoeira
# Processing Record 13 of Set 7 | fenton
# Processing Record 14 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 7 | inhambane
# Processing Record 16 of Set 7 | maningrida
# Processing Record 17 of Set 7 | kassala
# Processing Record 18 of Set 7 | shahr-e babak
# Processing Record 19 of Set 7 | mandera
# Processing Record 20 of Set 7 | lashio
# Processing Record 21 of Set 7 | karamay
# City not found. Skipping...
# Processing Record 22 of Set 7 | varadero
# Processing Record 23 of Set 7 | vao
# Processing Record 24 of Set 7 | nouakchott
# Processing Record 25 of Set 7 | lorengau
# Processing Record 26 of Set 7 | linhares
# Processing Record 27 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 28 of Set 7 | mae hong son
# Processing Record 29 of Set 7 | victoria point
# Processing Record 30 of Set 7 | praya
# Processing Record 31 of Set 7 | ola
# Processing Record 32 of Set 7 | road town
# Processing Record 33 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 34 of Set 7 | biak
# Processing Record 35 of Set 7 | zhanaozen
# Processing Record 36 of Set 7 | derzhavinsk
# Processing Record 37 of Set 7 | port moresby
# Processing Record 38 of Set 7 | mayor pablo lagerenza
# Processing Record 39 of Set 7 | jamkhed
# Processing Record 40 of Set 7 | candelaria
# Processing Record 41 of Set 7 | cabedelo
# Processing Record 42 of Set 7 | perth
# Processing Record 43 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 7 | sibu
# Processing Record 45 of Set 7 | naron
# Processing Record 46 of Set 7 | northam
# Processing Record 47 of Set 7 | lakes entrance
# Processing Record 48 of Set 7 | kavaratti
# Processing Record 49 of Set 7 | ayan
# Processing Record 50 of Set 7 | narrabri
# Processing Record 1 of Set 8 | angren
# Processing Record 2 of Set 8 | ballina
# Processing Record 3 of Set 8 | vila franca do campo
# Processing Record 4 of Set 8 | sioux lookout
# Processing Record 5 of Set 8 | floriano
# Processing Record 6 of Set 8 | qandala
# Processing Record 7 of Set 8 | corcoran
# Processing Record 8 of Set 8 | victor harbor
# Processing Record 9 of Set 8 | koygorodok
# Processing Record 10 of Set 8 | leticia
# Processing Record 11 of Set 8 | sabang
# Processing Record 12 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 8 | lucea
# Processing Record 14 of Set 8 | hede
# Processing Record 15 of Set 8 | hofn
# Processing Record 16 of Set 8 | smithers
# Processing Record 17 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 18 of Set 8 | lebu
# Processing Record 19 of Set 8 | saurimo
# Processing Record 20 of Set 8 | kavieng
# Processing Record 21 of Set 8 | mongagua
# Processing Record 22 of Set 8 | longyan
# Processing Record 23 of Set 8 | meulaboh
# Processing Record 24 of Set 8 | jiwani
# Processing Record 25 of Set 8 | zhengjiatun
# Processing Record 26 of Set 8 | umm ruwabah
# City not found. Skipping...
# Processing Record 27 of Set 8 | yomou
# Processing Record 28 of Set 8 | burica
# City not found. Skipping...
# Processing Record 29 of Set 8 | matagami
# Processing Record 30 of Set 8 | san alberto
# Processing Record 31 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 32 of Set 8 | san quintin
# Processing Record 33 of Set 8 | saldanha
# Processing Record 34 of Set 8 | young
# Processing Record 35 of Set 8 | dunedin
# Processing Record 36 of Set 8 | bela
# Processing Record 37 of Set 8 | petatlan
# Processing Record 38 of Set 8 | ajra
# Processing Record 39 of Set 8 | kysyl-syr
# Processing Record 40 of Set 8 | hovd
# Processing Record 41 of Set 8 | kontagora
# Processing Record 42 of Set 8 | chlorakas
# Processing Record 43 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 44 of Set 8 | camana
# Processing Record 45 of Set 8 | guerrero negro
# Processing Record 46 of Set 8 | komsomolskiy
# Processing Record 47 of Set 8 | beringovskiy
# Processing Record 48 of Set 8 | manuk mangkaw
# Processing Record 49 of Set 8 | leningradskiy
# Processing Record 50 of Set 8 | hirara
# Processing Record 1 of Set 9 | pathein
# Processing Record 2 of Set 9 | asyut
# Processing Record 3 of Set 9 | ondangwa
# Processing Record 4 of Set 9 | havoysund
# Processing Record 5 of Set 9 | arman
# Processing Record 6 of Set 9 | mount gambier
# Processing Record 7 of Set 9 | san lorenzo
# Processing Record 8 of Set 9 | bestobe
# Processing Record 9 of Set 9 | iowa city
# Processing Record 10 of Set 9 | moroni
# Processing Record 11 of Set 9 | malpe
# Processing Record 12 of Set 9 | polyanka
# Processing Record 13 of Set 9 | huazolotitlan
# City not found. Skipping...
# Processing Record 14 of Set 9 | saint-georges
# Processing Record 15 of Set 9 | paita
# Processing Record 16 of Set 9 | richards bay
# Processing Record 17 of Set 9 | turukhansk
# Processing Record 18 of Set 9 | mercedes
# Processing Record 19 of Set 9 | makakilo city
# Processing Record 20 of Set 9 | nisia floresta
# Processing Record 21 of Set 9 | sabha
# Processing Record 22 of Set 9 | tinskoy
# Processing Record 23 of Set 9 | russell
# Processing Record 24 of Set 9 | zhigansk
# Processing Record 25 of Set 9 | batagay
# Processing Record 26 of Set 9 | san patricio
# Processing Record 27 of Set 9 | damietta
# Processing Record 28 of Set 9 | balod
# Processing Record 29 of Set 9 | proletariy
# Processing Record 30 of Set 9 | wladyslawowo
# Processing Record 31 of Set 9 | upata
# Processing Record 32 of Set 9 | chhuikhadan
# Processing Record 33 of Set 9 | kahului
# Processing Record 34 of Set 9 | kawhia
# Processing Record 35 of Set 9 | goya
# Processing Record 36 of Set 9 | port-gentil
# Processing Record 37 of Set 9 | banyo
# Processing Record 38 of Set 9 | mafinga
# Processing Record 39 of Set 9 | huntington beach
# Processing Record 40 of Set 9 | bulancak
# Processing Record 41 of Set 9 | codrington
# Processing Record 42 of Set 9 | leshukonskoye
# Processing Record 43 of Set 9 | sola
# Processing Record 44 of Set 9 | ca mau
# Processing Record 45 of Set 9 | srandakan
# Processing Record 46 of Set 9 | grindavik
# Processing Record 47 of Set 9 | husavik
# Processing Record 48 of Set 9 | sturgis
# Processing Record 49 of Set 9 | impfondo
# Processing Record 50 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 10 | tautira
# Processing Record 2 of Set 10 | ayagoz
# Processing Record 3 of Set 10 | izazi
# Processing Record 4 of Set 10 | gasa
# Processing Record 5 of Set 10 | eslov
# Processing Record 6 of Set 10 | mount darwin
# Processing Record 7 of Set 10 | eyl
# Processing Record 8 of Set 10 | alice springs
# Processing Record 9 of Set 10 | muros
# Processing Record 10 of Set 10 | shimoda
# Processing Record 11 of Set 10 | kongolo
# Processing Record 12 of Set 10 | hervey bay
# Processing Record 13 of Set 10 | zambezi
# Processing Record 14 of Set 10 | iquitos
# Processing Record 15 of Set 10 | san carlos de bariloche
# Processing Record 16 of Set 10 | sungurlu
# Processing Record 17 of Set 10 | pisa
# Processing Record 18 of Set 10 | badarpur
# Processing Record 19 of Set 10 | jvari
# Processing Record 20 of Set 10 | luanda
# Processing Record 21 of Set 10 | sao joao da barra
# Processing Record 22 of Set 10 | micheweni
# Processing Record 23 of Set 10 | kushima
# Processing Record 24 of Set 10 | phalombe
# Processing Record 25 of Set 10 | palanga
# Processing Record 26 of Set 10 | xiaoweizhai
# Processing Record 27 of Set 10 | pisco
# Processing Record 28 of Set 10 | gurskoye
# City not found. Skipping...
# Processing Record 29 of Set 10 | ashland
# Processing Record 30 of Set 10 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 31 of Set 10 | muravlenko
# Processing Record 32 of Set 10 | jumla
# Processing Record 33 of Set 10 | havelock
# Processing Record 34 of Set 10 | lagoa
# Processing Record 35 of Set 10 | van buren
# Processing Record 36 of Set 10 | brae
# Processing Record 37 of Set 10 | marquette
# Processing Record 38 of Set 10 | hobyo
# Processing Record 39 of Set 10 | tessalit
# Processing Record 40 of Set 10 | omsukchan
# Processing Record 41 of Set 10 | la massana
# Processing Record 42 of Set 10 | honningsvag
# Processing Record 43 of Set 10 | peniche
# Processing Record 44 of Set 10 | korla
# Processing Record 45 of Set 10 | la palma
# Processing Record 46 of Set 10 | artesia
# Processing Record 47 of Set 10 | warrnambool
# Processing Record 48 of Set 10 | mizdah
# Processing Record 49 of Set 10 | ozernovskiy
# Processing Record 50 of Set 10 | dingle
# Processing Record 1 of Set 11 | piura
# Processing Record 2 of Set 11 | sibolga
# Processing Record 3 of Set 11 | safford
# Processing Record 4 of Set 11 | okhotsk
# Processing Record 5 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 11 | nargana
# Processing Record 7 of Set 11 | wukari
# Processing Record 8 of Set 11 | paoua
# Processing Record 9 of Set 11 | segou
# Processing Record 10 of Set 11 | sosnovo-ozerskoye
# Processing Record 11 of Set 11 | itaiba
# Processing Record 12 of Set 11 | huarmey
# Processing Record 13 of Set 11 | pisz
# Processing Record 14 of Set 11 | neuquen
# Processing Record 15 of Set 11 | newtonmore
# Processing Record 16 of Set 11 | wadi musa
# Processing Record 17 of Set 11 | klyuchi
# Processing Record 18 of Set 11 | winnemucca
# Processing Record 19 of Set 11 | waconia
# Processing Record 20 of Set 11 | awjilah
# Processing Record 21 of Set 11 | nabire
# Processing Record 22 of Set 11 | abnub
# Processing Record 23 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 24 of Set 11 | smidovich
# Processing Record 25 of Set 11 | shelburne
# Processing Record 26 of Set 11 | pacific grove
# Processing Record 27 of Set 11 | aguimes
# Processing Record 28 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 29 of Set 11 | corn island
# Processing Record 30 of Set 11 | senneterre
# Processing Record 31 of Set 11 | komsomolsk
# Processing Record 32 of Set 11 | mamallapuram
# Processing Record 33 of Set 11 | forst
# Processing Record 34 of Set 11 | ulladulla
# Processing Record 35 of Set 11 | vestbygda
# City not found. Skipping...
# Processing Record 36 of Set 11 | pompeia
# Processing Record 37 of Set 11 | bardiyah
# Processing Record 38 of Set 11 | ous
# Processing Record 39 of Set 11 | pella
# Processing Record 40 of Set 11 | vibo valentia
# Processing Record 41 of Set 11 | sorong
# Processing Record 42 of Set 11 | milkovo
# Processing Record 43 of Set 11 | deputatskiy
# Processing Record 44 of Set 11 | sambava
# Processing Record 45 of Set 11 | hualmay
# Processing Record 46 of Set 11 | pitimbu
# Processing Record 47 of Set 11 | oppdal
# Processing Record 48 of Set 11 | fare
# Processing Record 49 of Set 11 | nkhotakota
# Processing Record 50 of Set 11 | emerald
# Processing Record 1 of Set 12 | laibin
# Processing Record 2 of Set 12 | methoni
# Processing Record 3 of Set 12 | sobolevo
# Processing Record 4 of Set 12 | yar-sale
# Processing Record 5 of Set 12 | rio gallegos
# Processing Record 6 of Set 12 | scarborough
# Processing Record 7 of Set 12 | bandarbeyla
# Processing Record 8 of Set 12 | oussouye
# Processing Record 9 of Set 12 | amberley
# Processing Record 10 of Set 12 | nurota
# Processing Record 11 of Set 12 | hinton
# Processing Record 12 of Set 12 | nome
# Processing Record 13 of Set 12 | poum
# Processing Record 14 of Set 12 | nova vicosa
# Processing Record 15 of Set 12 | labrea
# Processing Record 16 of Set 12 | ust-koksa
# Processing Record 17 of Set 12 | kez
# Processing Record 18 of Set 12 | great falls
# Processing Record 19 of Set 12 | atambua
# Processing Record 20 of Set 12 | linxia
# Processing Record 21 of Set 12 | noumea
# Processing Record 22 of Set 12 | flinders
# Processing Record 23 of Set 12 | saquena
# Processing Record 24 of Set 12 | tsabong
# Processing Record 25 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 26 of Set 12 | oktyabrskiy
# Processing Record 27 of Set 12 | ganzhou
# Processing Record 28 of Set 12 | acapulco
# Processing Record 29 of Set 12 | changping
# Processing Record 30 of Set 12 | soyo
# Processing Record 31 of Set 12 | maarsen
# City not found. Skipping...
# Processing Record 32 of Set 12 | ilulissat
# Processing Record 33 of Set 12 | svetlyy
# Processing Record 34 of Set 12 | cap malheureux
# Processing Record 35 of Set 12 | usogorsk
# Processing Record 36 of Set 12 | karlskrona
# Processing Record 37 of Set 12 | matay
# Processing Record 38 of Set 12 | port shepstone
# Processing Record 39 of Set 12 | ustye
# Processing Record 40 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 41 of Set 12 | boende
# Processing Record 42 of Set 12 | tabou
# Processing Record 43 of Set 12 | laguna
# Processing Record 44 of Set 12 | lazaro cardenas
# Processing Record 45 of Set 12 | brownwood
# Processing Record 46 of Set 12 | goma
# Processing Record 47 of Set 12 | aanekoski
# Processing Record 48 of Set 12 | salto del guaira
# Processing Record 49 of Set 12 | yulara
# Processing Record 50 of Set 12 | bonthe
# Processing Record 1 of Set 13 | praia da vitoria
# Processing Record 2 of Set 13 | khandyga
# Processing Record 3 of Set 13 | zyryanka
# Processing Record 4 of Set 13 | burgersdorp
# Processing Record 5 of Set 13 | ara
# Processing Record 6 of Set 13 | new glasgow
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(5)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Tasiilaq  65.6145  -37.6368     33.96        71         100       14.03
# 1     Sorland  67.6670   12.6934     41.83        84          97       23.04
# 2  Bredasdorp -34.5322   20.0403     47.52        74          14        4.92
# 3      Avarua -21.2078 -159.7750     78.85        73          90       11.50
# 4    Hermanus -34.4187   19.2345     51.91        66          22        4.21
#
#   Current Description Country                 Date
# 0     overcast clouds      GL  2021-05-21 23:36:18
# 1     overcast clouds      NO  2021-05-21 23:37:27
# 2          few clouds      ZA  2021-05-21 23:36:12
# 3     overcast clouds      CK  2021-05-21 23:36:17
# 4          few clouds      ZA  2021-05-21 23:36:13

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(5)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Tasiilaq      GL  65.6145  -37.6368     33.96        71         100
# 1     Sorland      NO  67.6670   12.6934     41.83        84          97
# 2  Bredasdorp      ZA -34.5322   20.0403     47.52        74          14
# 3      Avarua      CK -21.2078 -159.7750     78.85        73          90
# 4    Hermanus      ZA -34.4187   19.2345     51.91        66          22
#
#    Wind Speed Current Description
# 0       14.03     overcast clouds
# 1       23.04     overcast clouds
# 2        4.92          few clouds
# 3       11.50     overcast clouds
# 4        4.21          few clouds

# %%
city_data_df.to_csv('Weather_Database/WeatherPy_database.csv')
